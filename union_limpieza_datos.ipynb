# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_columns", None)

# %%
df1=pd.read_csv("world-data-2023_part1.csv", index_col=0)

# %%
df2=pd.read_csv("world-data-2023_part2.csv", index_col=0)

# %%
df1.sample(2)
# Out:
#     Country Density\r\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 139  Poland                124           PL                46.90%
# 23   Brazil                 25           BR                33.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 139        312,685           191,000       10.20          48.0
# 23       8,515,770           730,000       13.92          55.0
#
#     Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 139             Warsaw       299,037  114.11          2.20%           PLN
# 23             Bras���       462,299   167.4          3.70%           BRL
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 139            1.46            30.90%         $1.07
# 23             1.73            58.90%         $1.02

# %%
df2.sample(2)
# Out:
#                       GDP Gross primary education enrollment (%)  \
# 186  $21,427,700,000,000                                 101.80%
# 141     $183,466,208,791                                 103.80%
#
#     Gross tertiary education enrollment (%)  Infant mortality   Largest city  \
# 186                                  88.20%               5.6  New York City
# 141                                  17.90%               5.8           Doha
#
#      Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 186             78.5                      19.0       $7.25                NaN
# 141             80.1                       9.0          NaN            Arabic
#
#     Out of pocket health expenditure  Physicians per thousand   Population  \
# 186                           11.10%                     2.61  328,239,523
# 141                            6.20%                     2.49    2,832,067
#
# ...

# %%
pd.Series(df1.columns)
# Out:
# 0                   Country
# 1        Density\r\n(P/Km2)
# 2              Abbreviation
# 3     Agricultural Land( %)
# 4            Land Area(Km2)
# 5         Armed Forces size
# 6                Birth Rate
# 7              Calling Code
# 8        Capital/Major City
# 9             Co2-Emissions
# 10                      CPI
# 11           CPI Change (%)
# 12            Currency-Code
# 13           Fertility Rate
# 14        Forested Area (%)
# 15           Gasoline Price
# dtype: str

# %%
pd.Series(df2.columns)
# Out:
# 0                                           GDP
# 1        Gross primary education enrollment (%)
# 2       Gross tertiary education enrollment (%)
# 3                              Infant mortality
# 4                                  Largest city
# 5                               Life expectancy
# 6                      Maternal mortality ratio
# 7                                  Minimum wage
# 8                             Official language
# 9              Out of pocket health expenditure
# 10                      Physicians per thousand
# 11                                   Population
# 12    Population: Labor force participation (%)
# 13                              Tax revenue (%)
# 14                               Total tax rate
# 15                            Unemployment rate
# 16                             Urban_population
# 17                                      country
# 18                                  coordinates
# dtype: str

# %%
df1[df1["Country"] == "Greece"]
# Out:
#    Country Density\r\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 66  Greece                 81           GR                47.60%
#
#    Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 66        131,957           146,000         8.1          30.0
#
#    Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 66             Athens        62,434  101.87          0.20%           EUR
#
#     Fertility Rate Forested Area (%) Gasoline Price
# 66            1.35            31.70%         $1.54

# %%
df2[df2["country"] == "Greece"]
# Out:
#                   GDP Gross primary education enrollment (%)  \
# 66  $209,852,761,469                                  99.60%
#
#    Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 66                                 136.60%               3.6    Macedonia
#
#     Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 66             81.3                       3.0       $4.46              Greek
#
#    Out of pocket health expenditure  Physicians per thousand  Population  \
# 66                           35.50%                     5.48  10,716,322
#
#    Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 66                                    51.80%          26.20%         51.90%
#
#    Unemployment rate Urban_population country                  coordinates
# 66            17.24%        8,507,474  Greece  ('39.074208 ', '21.824312')

# %%
df1.shape
# Out:
# (195, 16)

# %%
df2.shape
# Out:
# (195, 19)

# %%
dfmerge = df1.merge(df2, left_on="Country", right_on="country")

# %%
dfmerge.head(2)
# Out:
#        Country Density\r\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan                 60           AF                58.10%
# 1      Albania                105           AL                43.10%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
#
#    Fertility Rate Forested Area (%) Gasoline Price               GDP  \
# 0            4.47             2.10%         $0.70   $19,101,353,833
# 1            1.62            28.10%         $1.36   $15,278,077,447
#
#   Gross primary education enrollment (%)  \
# 0                                104.00%
# 1                                107.00%
#
# ...

# %%
dfmerge.shape
# Out:
# (195, 35)

# %%
dfjoin = df1.join(df2)

# %%
dfjoin.sample(5)
# Out:
#                       Country Density\r\n(P/Km2) Abbreviation  \
# 33   Central African Republic                  8           CF
# 193                    Zambia                 25           ZM
# 135          Papua New Guinea                 20           PG
# 123               New Zealand                 18           NZ
# 59                    Finland                 18           FI
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 33                  8.20%        622,984             8,000       35.35
# 193                32.10%        752,618            16,000       36.19
# 135                 2.60%        462,840             4,000       27.07
# 123                40.50%        268,838             9,000       11.98
# 59                  7.50%        338,145            25,000        8.60
#
#      Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 33          236.0             Bangui           297  186.86         37.10%
# ...

# %%
pd.Series(dfjoin.columns)
# Out:
# 0                                       Country
# 1                            Density\r\n(P/Km2)
# 2                                  Abbreviation
# 3                         Agricultural Land( %)
# 4                                Land Area(Km2)
# 5                             Armed Forces size
# 6                                    Birth Rate
# 7                                  Calling Code
# 8                            Capital/Major City
# 9                                 Co2-Emissions
# 10                                          CPI
# 11                               CPI Change (%)
# 12                                Currency-Code
# 13                               Fertility Rate
# 14                            Forested Area (%)
# 15                               Gasoline Price
# 16                                          GDP
# 17       Gross primary education enrollment (%)
# 18      Gross tertiary education enrollment (%)
# 19                             Infant mortality
# ...

# %%
pd.Series(dfmerge.columns)
# Out:
# 0                                       Country
# 1                            Density\r\n(P/Km2)
# 2                                  Abbreviation
# 3                         Agricultural Land( %)
# 4                                Land Area(Km2)
# 5                             Armed Forces size
# 6                                    Birth Rate
# 7                                  Calling Code
# 8                            Capital/Major City
# 9                                 Co2-Emissions
# 10                                          CPI
# 11                               CPI Change (%)
# 12                                Currency-Code
# 13                               Fertility Rate
# 14                            Forested Area (%)
# 15                               Gasoline Price
# 16                                          GDP
# 17       Gross primary education enrollment (%)
# 18      Gross tertiary education enrollment (%)
# 19                             Infant mortality
# ...

# %%
#Se puede usar merge porque coincide la columna "country" en los dos dataframes
#y join porque coinciden los indices

# %% [markdown]
# Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas.

# %%
dfmerge.drop(columns=["Country"], inplace=True)

# %%
dfmerge.sample(2)
# Out:
#     Density\r\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 78                 151           ID                31.50%      1,904,569
# 183                 75           UA                71.70%        603,550
#
#     Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 78            676,000       18.07          62.0            Jakarta
# 183           297,000        8.70         380.0               Kyiv
#
#     Co2-Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 78        563,325  151.18          3.00%           IDR            2.31
# 183       202,250  281.66          7.90%           UAH            1.30
#
#     Forested Area (%) Gasoline Price                  GDP  \
# 78             49.90%         $0.63   $1,119,190,780,753
# 183            16.70%         $0.83     $153,781,069,118
#
#     Gross primary education enrollment (%)  \
# 78                                 106.40%
# 183                                 99.00%
#
# ...

# %%
dfmerge.shape
# Out:
# (195, 34)

# %%
dfmerge.columns
# Out:
# Index(['Density\r\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'country',
#        'coordinates'],
#       dtype='str')

# %% [markdown]
# Los nombres de las columnas no son homogeneos. Cambia los nombres de las columnas de tal forma que:
#
# No tengan espacios.
#
# Estén en minúscula.
#
# No tengan paréntesis, es decir, quitar "(%)", "(Km2)".
#
# Algunas columnas tiene "\n". Eliminalos de los nombres de las columnas.
#
# Algunas columnas tienen ":". Eliminalos de los nombres de las columnas.

# %%
nuevas_columnas = {columna: columna.lower().replace(" ", "-").replace("(%)", "").replace("(Km2)", "").replace("\n", "").replace(":", "") for columna in dfmerge.columns}

# %%
nuevas_columnas
# Out:
# {'density\r\n(p/km2)': 'density\r(p/km2)',
#  'abbreviation': 'abbreviation',
#  'agricultural-land(-%)': 'agricultural-land(-%)',
#  'land-area(km2)': 'land-area(km2)',
#  'armed-forces-size': 'armed-forces-size',
#  'birth-rate': 'birth-rate',
#  'calling-code': 'calling-code',
#  'capital/major-city': 'capital/major-city',
#  'co2-emissions': 'co2-emissions',
#  'cpi': 'cpi',
#  'cpi-change-(%)': 'cpi-change-',
#  'currency-code': 'currency-code',
#  'fertility-rate': 'fertility-rate',
#  'forested-area-(%)': 'forested-area-',
#  'gasoline-price': 'gasoline-price',
#  'gdp': 'gdp',
#  'gross-primary-education-enrollment-(%)': 'gross-primary-education-enrollment-',
#  'gross-tertiary-education-enrollment-(%)': 'gross-tertiary-education-enrollment-',
#  'infant-mortality': 'infant-mortality',
#  'largest-city': 'largest-city',
#  'life-expectancy': 'life-expectancy',
#  'maternal-mortality-ratio': 'maternal-mortality-ratio',
#  'minimum-wage': 'minimum-wage',
# ...

# %%
dfmerge.rename(columns= nuevas_columnas, inplace=True)

# %%
dfmerge.sample(2)
# Out:
#     density\r\n(p/km2) abbreviation agricultural-land(-%) land-area(km2)  \
# 17                  17           BZ                 7.00%         22,966
# 103                 99           MY                26.30%        329,847
#
#     armed-forces-size  birth-rate  calling-code capital/major-city  \
# 17              2,000       20.79         501.0           Belmopan
# 103           136,000       16.75          60.0       Kuala Lumpur
#
#     co2-emissions     cpi cpi-change-(%) currency-code  fertility-rate  \
# 17            568  105.68         -0.90%           BZD            2.31
# 103       248,289  121.46          0.70%           MYR            2.00
#
#     forested-area-(%) gasoline-price                gdp  \
# 17             59.70%         $1.13     $1,879,613,600
# 103            67.60%         $0.45   $364,701,517,788
#
#     gross-primary-education-enrollment-(%)  \
# 17                                 111.70%
# 103                                105.30%
#
# ...

# %%
dfmerge.columns.str.replace("(%)", "")
# Out:
# Index(['density\r\n(p/km2)', 'abbreviation', 'agricultural-land(-%)',
#        'land-area(km2)', 'armed-forces-size', 'birth-rate', 'calling-code',
#        'capital/major-city', 'co2-emissions', 'cpi', 'cpi-change-',
#        'currency-code', 'fertility-rate', 'forested-area-', 'gasoline-price',
#        'gdp', 'gross-primary-education-enrollment-',
#        'gross-tertiary-education-enrollment-', 'infant-mortality',
#        'largest-city', 'life-expectancy', 'maternal-mortality-ratio',
#        'minimum-wage', 'official-language', 'out-of-pocket-health-expenditure',
#        'physicians-per-thousand', 'population',
#        'population:-labor-force-participation-', 'tax-revenue-',
#        'total-tax-rate', 'unemployment-rate', 'urban_population', 'country',
#        'coordinates'],
#       dtype='str')
