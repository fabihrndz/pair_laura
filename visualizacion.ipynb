# %%
import pandas as pd

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
df = pd.read_csv("world_data_full_apply_nulos.csv", index_col=0) 
df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# ...

# %% [markdown]
# ¿Cómo se distribuye la tasa de natalidad en el conjunto de datos? ¿Hay algún patrón evidente?

# %%
sns.histplot(data=df, x="birth_rate");

# %%
sns.histplot(data=df[df["country"]=="Spain"], x="birth_rate");

# %%
df[df["country"]=="Spain"]
# Out:
#     country  density abbreviation  agricultural_land  land_area  \
# 164   Spain     94.0           ES               52.6     505.37
#
#      armed_forces_size  birth_rate  calling_code capital/major_city  \
# 164              196.0         7.9          34.0             Madrid
#
#      co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 164        244.002  110.96         0.7           EUR            1.26
#
#      forested_area  gasoline_price           gdp  \
# 164           36.9            1.26  1.394116e+12
#
#      gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 164                               102.7                                 88.9
#
#      infant_mortality largest_city  life_expectancy  maternal_mortality_ratio  \
# 164               2.5       Madrid             83.3                       4.0
#
#      minimum_wage official_language  out_of_pocket_health_expenditure  \
# ...

# %% [markdown]
# ¿Existe una relación aparente entre la tasa de mortalidad infantil y la esperanza de vida? Proporciona una breve descripción de los patrones que observes.

# %%
sns.scatterplot(data=df,x="infant_mortality", y= "life_expectancy")
# Out:
# <Axes: xlabel='infant_mortality', ylabel='life_expectancy'>

# %%
sns.histplot(data=df, x="infant_mortality");

# %%
sns.histplot(data=df, x="life_expectancy")
# Out:
# <Axes: xlabel='life_expectancy', ylabel='Count'>

# %% [markdown]
# ¿Cuál es la mediana de la esperanza de vida en Europa? Proporciona un rango intercuartil aproximado y verifica si existen valores atípicos.

# %%
sns.boxplot(data=df, x="life_expectancy")
# Out:
# <Axes: xlabel='life_expectancy'>

# %%
df["life_expectancy"].describe().T
# Out:
# count    187.000000
# mean      72.279679
# std        7.483661
# min       52.800000
# 25%       67.000000
# 50%       73.200000
# 75%       77.500000
# max       85.400000
# Name: life_expectancy, dtype: float64

# %% [markdown]
# Existen relaciones visibles entre la tasa de natalidad y las siguientes variables: tasa de mortalidad infantil, esperanza de vida, densidad de población y población urbana? Usa un subplot. Describe cualquier patrón que encuentres.

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 5))
sns.scatterplot(data=df,x="infant_mortality", y= "life_expectancy", ax=axes[0])
sns.scatterplot(data=df,x="density", y= "urban_population", ax=axes[1])
# Out:
# <Axes: xlabel='density', ylabel='urban_population'>
